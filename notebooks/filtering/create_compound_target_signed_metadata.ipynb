# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import re
from src.config import *

# %% [markdown]
# # Filter LINCS coumpound matedata
# - Read in metadata and ligand-receptor interaction resource
# - Set sign to activators and inhibitors and filter items where direction of interaction is not known
# - Save modified metadata for LINCS coupounds

# %% [markdown]
# ## Read in data

# %%
cp_info = pd.read_table(f'{LINCS_DATA_DIR}/compoundinfo_beta.txt', low_memory=False)
cp_info = cp_info.dropna(subset = 'moa')
cp_info_rec = cp_info[cp_info.moa.str.contains('receptor', case = False)]

# %%
# omnipath signed ligand-receptor interactions
lr_interactions = pd.read_csv('data/receptor_ligand_association/liana_omni_receptor_ligand_interactions_curated.csv', index_col =0)

# %%
targets = set(lr_interactions.target_genesymbol)
moas = set(cp_info_rec.moa)

# %%
data = cp_info[cp_info.target.isin(targets) | cp_info.moa.isin(moas)]

# %% [markdown]
# ## Set sign

# %%
activators=['agonist', 'activator', 'stimulant', 'enhancer', 'reactivator', 'inducer', 'positive']
inhibitors=['inhibitor', 'antagonist', 'blocker', 'downregulator', 'destabilizer', 'negative']

# %%
def add_sign(s):
    if s['activator'] ==1:
        return 1
    elif s['inhibitor'] ==1:
        return -1
    else: 
        return 0

# %%
data["activator"] = data['moa'].apply(lambda x: 1 if any(i in activators for i in re.split('-| ', x.lower())) else 0)
data["inhibitor"] = data['moa'].apply(lambda x: 1 if any(i in inhibitors for i in re.split('-| ', x.lower())) else 0)
data['sign'] = data.apply(add_sign, axis=1)
# Out:
# /var/folders/ld/gy00m33j1pn81v2x1sj_h3pm0000gn/T/ipykernel_73285/3657626652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["activator"] = data['moa'].apply(lambda x: 1 if any(i in activators for i in re.split('-| ', x.lower())) else 0)
# /var/folders/ld/gy00m33j1pn81v2x1sj_h3pm0000gn/T/ipykernel_73285/3657626652.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["inhibitor"] = data['moa'].apply(lambda x: 1 if any(i in inhibitors for i in re.split('-| ', x.lower())) else 0)
# /var/folders/ld/gy00m33j1pn81v2x1sj_h3pm0000gn/T/ipykernel_73285/3657626652.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sign'] = data.apply(add_sign, axis=1)

# %%
# delete rows with sign = 0 - inhibitor or activator synonyms not in rows
data[(data['cmap_name'] == 'AMN-082') & (data['target'] == 'GRM7')]
# be careful with it, because in some cases on the same receptor is in modulator (sign not given) and also activator... eg.
# Out:
#              pert_id cmap_name target  \
# 36840  BRD-K23335153   AMN-082   GRM7
# 39285  BRD-K23335153   AMN-082   GRM7
#
#                                                     moa  \
# 36840                      Glutamate receptor modulator
# 39285  Glutamate receptor positive allosteric modulator
#
#                                    canonical_smiles  \
# 36840  C(CNC(c1ccccc1)c1ccccc1)NC(c1ccccc1)c1ccccc1
# 39285  C(CNC(c1ccccc1)c1ccccc1)NC(c1ccccc1)c1ccccc1
#
#                          inchi_key compound_aliases  activator  inhibitor  \
# 36840  DTZDSNQYNPNCPK-UHFFFAOYSA-N              NaN          0          0
# 39285  DTZDSNQYNPNCPK-UHFFFAOYSA-N              NaN          1          0
#
#        sign
# 36840     0
# 39285     1

# %%
# delete rows with sign = 0 - inhibitor or activator synonyms not in rows
data = data[data['sign'] != 0]

# %%
# There are some drugs that are agonists and antagonists on the same receptor target wg. melatonin/tramadol/TFMPP (20)
data[(data['cmap_name'] == 'TFMPP') & (data['target'] == 'HTR1D')]
# Out:
#            pert_id cmap_name target                            moa  \
# 774  BRD-K94887716     TFMPP  HTR1D     Serotonin receptor agonist
# 825  BRD-K94887716     TFMPP  HTR1D  Serotonin receptor antagonist
#
#                canonical_smiles                    inchi_key compound_aliases  \
# 774  FC(F)(F)c1cccc(c1)N2CCNCC2  KKIMDKMETPPURN-UHFFFAOYSA-N            tfmpp
# 825  FC(F)(F)c1cccc(c1)N2CCNCC2  KKIMDKMETPPURN-UHFFFAOYSA-N            tfmpp
#
#      activator  inhibitor  sign
# 774          1          0     1
# 825          0          1    -1

# %% [markdown]
# Filter out drugs with multiple sign on the same receptor

# %%
drugs_to_delete = data[['cmap_name', 'target', 'sign']].groupby(['cmap_name', 'target']).nunique('sign')
drugs_to_delete = list(drugs_to_delete[drugs_to_delete.sign > 1].index.get_level_values(0))

# %%
data = data[~data.cmap_name.isin(drugs_to_delete)]

# %%
data.head(3)
# Out:
#            pert_id  cmap_name target            moa  \
# 604  BRD-K39381259       DMH1  ACVR1  ALK inhibitor
# 627  BRD-K42828737  sunitinib   FLT1  KIT inhibitor
# 628  BRD-K42828737  sunitinib   FLT3  KIT inhibitor
#
#                                       canonical_smiles  \
# 604    CC(C)Oc1ccc(cc1)-c1cnc2c(cnn2c1)-c1ccnc2ccccc12
# 627  CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
# 628  CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
#
#                        inchi_key  compound_aliases  activator  inhibitor  sign
# 604  JMIFGARJSWXZSH-UHFFFAOYSA-N             DMH-1          0          1    -1
# 627  WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1    -1
# 628  WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1    -1

# %% [markdown]
# ## Save data

# %%
data
# Out:
#              pert_id          cmap_name target  \
# 604    BRD-K39381259               DMH1  ACVR1
# 627    BRD-K42828737          sunitinib   FLT1
# 628    BRD-K42828737          sunitinib   FLT3
# 629    BRD-K42828737          sunitinib   FLT4
# 630    BRD-K42828737          sunitinib    KDR
# ...              ...                ...    ...
# 39309  BRD-A61599461      BRD-A61599461   TSHR
# 39310  BRD-A81177136              KN-62  P2RX7
# 39315  BRD-K99504665  goserelin-acetate  GNRHR
# 39316  BRD-K62685538        triptorelin  GNRHR
# 39317  BRD-K62221994            T-98475  GNRHR
#
#                                                      moa  \
# 604                                        ALK inhibitor
# 627                                        KIT inhibitor
# 628                                        KIT inhibitor
# 629                                        KIT inhibitor
# 630                                        KIT inhibitor
# ...                                                  ...
# 39309  Thyroid-stimulating hormone receptor inverse a...
# 39310  Calcium/calmodulin dependent protein kinase in...
# 39315  Gonadotropin releasing factor hormone receptor...
# 39316  Gonadotropin releasing factor hormone receptor...
# 39317  Gonadotropin releasing factor hormone receptor...
#
#                                         canonical_smiles  \
# 604      CC(C)Oc1ccc(cc1)-c1cnc2c(cnn2c1)-c1ccnc2ccccc12
# 627    CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
# 628    CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
# 629    CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
# 630    CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
# ...                                                  ...
# 39309  COc1ccc(cc1COc1c(C)cccc1C)C1Nc2ccccc2C(=O)N1Cc...
# 39310  CN(C(Cc1ccc(OS(=O)(=O)c2cccc3cnccc23)cc1)C(=O)...
# 39315  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 39316  CC(C)C[C@H](NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(...
# 39317  CC(C)OC(=O)c1cn(Cc2c(F)cccc2F)c3sc(c(CN(C)Cc4c...
#
#                          inchi_key  compound_aliases  activator  inhibitor  \
# 604    JMIFGARJSWXZSH-UHFFFAOYSA-N             DMH-1          0          1
# 627    WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1
# 628    WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1
# 629    WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1
# 630    WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1
# ...                            ...               ...        ...        ...
# 39309  ODFGSMOTQLYMHU-UHFFFAOYSA-N               NaN          1          0
# 39310  RJVLFQBBRSMWHX-UHFFFAOYSA-N               NaN          0          1
# 39315  BLCLNMBMMGCOAS-URPVMXJPSA-N               NaN          1          0
# 39316  VXKHXGOKWPXYNA-PGBVPBMZSA-N               NaN          1          0
# 39317  RANJJVIMTOIWIN-UHFFFAOYSA-N               NaN          0          1
#
#        sign
# 604      -1
# 627      -1
# 628      -1
# 629      -1
# 630      -1
# ...     ...
# 39309     1
# 39310    -1
# 39315     1
# 39316     1
# 39317    -1
#
# [3746 rows x 10 columns]

# %%
data.to_csv('data/filtered_lincs_meta/filtered_coumpound_info_to_receptor_perturbation_signatures_signed.csv')

# %%
data.head()
# Out:
#            pert_id  cmap_name target            moa  \
# 604  BRD-K39381259       DMH1  ACVR1  ALK inhibitor
# 627  BRD-K42828737  sunitinib   FLT1  KIT inhibitor
# 628  BRD-K42828737  sunitinib   FLT3  KIT inhibitor
# 629  BRD-K42828737  sunitinib   FLT4  KIT inhibitor
# 630  BRD-K42828737  sunitinib    KDR  KIT inhibitor
#
#                                       canonical_smiles  \
# 604    CC(C)Oc1ccc(cc1)-c1cnc2c(cnn2c1)-c1ccnc2ccccc12
# 627  CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
# 628  CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
# 629  CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
# 630  CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2/C(=O)Nc3ccc(F)...
#
#                        inchi_key  compound_aliases  activator  inhibitor  sign
# 604  JMIFGARJSWXZSH-UHFFFAOYSA-N             DMH-1          0          1    -1
# 627  WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1    -1
# 628  WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1    -1
# 629  WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1    -1
# 630  WINHZLLDWRZWRT-ATVHPVEESA-N  sunitinib-malate          0          1    -1
